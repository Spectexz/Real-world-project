# %% [markdown]
# ![eiffel-tower](images/eiffel-tower.png)
#
# As a distinguished AI Developer, you've been selected by Peterman Reality Tours, an internationally acclaimed tourism company, to undertake an influential project. This project requires you to harness the potential of OpenAI's API, to create an AI-powered travel guide for the culturally rich city of Paris.
#
# Your creation will become a virtual Parisian expert, delivering valuable insights into the city's iconic landmarks and hidden treasures. The AI will respond intelligently to a set of common questions, providing a more engaging and immersive travel planning experience for the clientele of Peterman Reality Tours.
#
# The ultimate aspiration is a user-friendly, AI-driven travel guide that significantly enhances the exploration of Paris. Users will be able to pre-define their questions and receive well-informed answers from the AI, providing a seamless and intuitive travel planning process.

# %%
import os
from openai import OpenAI

# Define the model to use
model = "gpt-4o-mini"

# Define the client
client = OpenAI()

# %% [markdown]
# Structure what i learn:
# conversation = [system, Q1]
# → API call → A1
# conversation = [system, Q1, A1, Q2]
# → API call → A2
# conversation = [system, Q1, A1, Q2, A2, Q3]
# → API call → A3

# %%
#creating a list of dictionaries
conversation = [
    {"role": "system", "content": "Write instructions here about being a Paris travel guide"},
    {"role": "user", "content": "How far away is the Louvre from the Eiffel Tower (in miles) if you are driving?"}
]

# %%
#Building the response
response = client.chat.completions.create(
    model = model,
    messages = conversation,
    temperature = 0.0,
    max_tokens = 100    
)

# %%
#Calling the response and adding conversation
answer1 = response.choices[0].message.content

conversation.append({"role": "assistant", "content": answer1})

#adding 2nd question
conversation.append({"role": "user", "content": "Where is the Arc de Triomphe?"})
#Building the response
response = client.chat.completions.create(
    model = model,
    messages = conversation,
    temperature = 0.0,
    max_tokens = 100    
)
answer2 = response.choices[0].message.content
conversation.append({"role": "assistant", "content": answer2})

#adding 3rd question
conversation.append({"role": "user", "content": "What are the must-see artworks at the Louvre Museum?"})
#Building the response
response = client.chat.completions.create(
    model = model,
    messages = conversation,
    temperature = 0.0,
    max_tokens = 100    
)
answer3 = response.choices[0].message.content
conversation.append({"role": "assistant", "content": answer3})

# %%
print(answer1,answer2,answer3)
# Out:
# The distance from the Louvre Museum to the Eiffel Tower is approximately 3 miles (about 5 kilometers) when driving. However, travel time can vary depending on traffic conditions. It's advisable to check a navigation app for the most accurate route and estimated travel time. The Arc de Triomphe is located at the western end of the Champs-Élysées in Paris, France. It stands at the center of Place Charles de Gaulle, a large roundabout that connects several major roads. The monument honors those who fought and died for France during the French Revolutionary and Napoleonic Wars and is one of the most famous landmarks in Paris. Visitors can access it via an underground pedestrian tunnel to ensure safety from the busy traffic around the roundabout. The Louvre Museum is home to an extensive collection of artworks, but several pieces are considered must-sees for any visitor. Here are some of the most iconic:
#
# 1. **Mona Lisa (La Joconde)** - Leonardo da Vinci's famous portrait is renowned for its enigmatic expression and masterful technique. It's one of the most visited artworks in the world.
#
# 2. **Venus de Milo** - This ancient Greek statue, believed to represent the goddess Aphrodite, is celebrated for its beauty
